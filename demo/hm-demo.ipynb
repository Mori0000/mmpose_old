# %%
import sys

from mmcv.image import imread

sys.path.append('/home/moriki/PoseEstimation/mmpose/')

from mmpose.apis import inference_topdown, init_model
from mmpose.registry import VISUALIZERS
from mmpose.structures import merge_data_samples

model_cfg = '/home/moriki/PoseEstimation/mmpose/configs/body_2d_keypoint/rtmpose/coco/rtmpose-s_8xb256-420e_coco-256x192.py'

ckpt = 'https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmpose-m_simcc-body7_pt-body7-halpe26_700e-256x192-4d3e73dd_20230605.pth'

device = 'cuda'

# init model
model = init_model(model_cfg, ckpt, device=device)

img_path = '/home/moriki/PoseEstimation/mmpose/data/coco/coco2014/images/test2014/COCO_test2014_000000000173.jpg'

# inference on a single image
batch_results = inference_topdown(model, img_path)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmpose/v1/projects/rtmposev1/rtmpose-m_simcc-body7_pt-body7-halpe26_700e-256x192-4d3e73dd_20230605.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for backbone.stem.0.conv.weight: copying a param with shape torch.Size([24, 3, 3, 3]) from checkpoint, the shape in current model is torch.Size([16, 3, 3, 3]).
# size mismatch for backbone.stem.0.bn.weight: copying a param with shape torch.Size([24]) from checkpoint, the shape in current model is torch.Size([16]).
# size mismatch for backbone.stem.0.bn.bias: copying a param with shape torch.Size([24]) from checkpoint, the shape in current model is torch.Size([16]).
# size mismatch for backbone.stem.0.bn.running_mean: copying a param with shape torch.Size([24]) from checkpoint, the shape in current model is torch.Size([16]).
# ...
